# %% [markdown]
# ### read the data in the cvs and create a dataframe

# %%
import pandas as pd
data = pd.read_csv('parks_1.csv')

# %%
data.head()
# Out:
#   Park Code               Park Name State     Acres  Latitude  Longitude
# 0      ACAD    Acadia National Park    ME   47390.0     44.35     -68.21
# 1      ARCH    Arches National Park    UT   76519.0     38.68    -109.57
# 2      BADL  Badlands National Park    SD  242756.0     43.75    -102.50
# 3      BIBE  Big Bend National Park    TX       NaN     29.25    -103.25
# 4      BISC  Biscayne National Park    FL  172924.0     25.65     -80.08

# %% [markdown]
# #### Expected output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Make the Park Code column the index of the dataframe

# %%
data = data.set_index('Park Code')

# %%
data.head()
# Out:
#                         Park Name State     Acres  Latitude  Longitude
# Park Code
# ACAD         Acadia National Park    ME   47390.0     44.35     -68.21
# ARCH         Arches National Park    UT   76519.0     38.68    -109.57
# BADL       Badlands National Park    SD  242756.0     43.75    -102.50
# BIBE       Big Bend National Park    TX       NaN     29.25    -103.25
# BISC       Biscayne National Park    FL  172924.0     25.65     -80.08

# %% [markdown]
# #### Expected output
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Using the dataframe. Please answer the questions below.

# %% [markdown]
# 1. Print the first five rows of the dataframe.
# 2. How many null values are in the Acres column
# 3. Fill in the missing values with either mean,median or mode. Give reason why you chose mean,median or mode.
# 4. How many parks are smaller than 10,000 acres?
# 5. What is the name of the park that has the code EVER?

# %%
#Print the first five rows of the dataframe.
data.head()
# Out:
#                         Park Name State     Acres  Latitude  Longitude
# Park Code
# ACAD         Acadia National Park    ME   47390.0     44.35     -68.21
# ARCH         Arches National Park    UT   76519.0     38.68    -109.57
# BADL       Badlands National Park    SD  242756.0     43.75    -102.50
# BIBE       Big Bend National Park    TX       NaN     29.25    -103.25
# BISC       Biscayne National Park    FL  172924.0     25.65     -80.08

# %%
#How many null values are in the Acres column
data['Acres'].isnull().sum()
# Out:
# 7

# %%
#Fill in the missing values with either mean,median or mode. Give reaason why you chose mean,median or mode.
data['Acres'] = data['Acres'].fillna((data['Acres'].mean()))

# %%
data.head()
# Out:
#                         Park Name State         Acres  Latitude  Longitude
# Park Code
# ACAD         Acadia National Park    ME   47390.00000     44.35     -68.21
# ARCH         Arches National Park    UT   76519.00000     38.68    -109.57
# BADL       Badlands National Park    SD  242756.00000     43.75    -102.50
# BIBE       Big Bend National Park    TX  958941.22449     29.25    -103.25
# BISC       Biscayne National Park    FL  172924.00000     25.65     -80.08

# %%
#How many parks are smaller than 10,000 acres?
(data['Acres'] < 10000 ).sum()
# Out:
# 1

# %%
#What is the name of the park that has the code EVER?
data.loc['EVER']['Park Name']
# Out:
# 'Everglades National Park'

# %%
data.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-0dc99c936dd2> in <module>
# ----> 1 data.loc[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962
#    1963         # fall thru to straight lookup
# -> 1964         self._validate_key(key, axis)
#    1965         return self._get_label(key, axis=axis)
#    1966
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1829
#    1830         if not is_list_like_indexer(key):
# ...
